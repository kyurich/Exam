# %%
import pandas as pd
import numpy as np
from scipy import stats
from sklearn.linear_model import LinearRegression
import matplotlib
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

# %%
import seaborn as sb

# %%
train = pd.read_csv('train.csv', header = None)
test = pd.read_csv('test.csv', header = None)
train.head()
# Out:
#    0       1       2       3       4         5         6         7   8
# 0  M  3.1110  2.4990  0.8160  5.8446  3.044700       NaN  1.992463   8
# 1  M  2.3715  1.8360  0.5355  2.1981  1.222069  0.545700       NaN   9
# 2  M  2.4990  2.0145  0.7140  2.7999  1.129650  0.650250  0.765000  11
# 3  M  3.2130  2.5245  0.8160  5.5743  2.534700  1.127100  1.606500  12
# 4  M  2.9325  2.2185  0.6885  5.0592  2.203200  1.254302       NaN  10

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10579 entries, 0 to 10578
# Data columns (total 9 columns):
# 0    10579 non-null object
# 1    10047 non-null float64
# 2    10051 non-null float64
# 3    10044 non-null float64
# 4    10055 non-null float64
# 5    10053 non-null float64
# 6    10073 non-null float64
# 7    10019 non-null float64
# 8    10579 non-null int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 743.9+ KB

# %%
train = train.fillna(train.mean())

# %%
train.describe()
# Out:
#                  1            2            3           4            5  \
# count  7377.000000  7377.000000  7377.000000  7377.00000  7377.000000
# mean      2.799561     2.191692     0.765755     4.46373     1.994835
# std       0.528612     0.443701     0.235002     2.32298     1.099375
# min       1.045500     0.790500     0.000000     0.21675     0.086700
# 25%       2.422500     1.887000     0.612000     2.62905     1.124550
# 50%       2.856000     2.244000     0.765000     4.26615     1.876800
# 75%       3.187500     2.499000     0.891556     6.00270     2.687700
# max       4.569913     3.776277     5.763000    14.17545     7.588800
#
#                  6            7            8
# count  7377.000000  7377.000000  7377.000000
# mean      1.008711     1.287787     9.702182
# std       0.543402     0.636059     1.891036
# min       0.028050     0.079050     7.000000
# 25%       0.583950     0.790500     8.000000
# 50%       0.940950     1.249500     9.000000
# ...

# %%
sb.set(style= 'darkgrid', context = 'notebook')
sb.pairplot(train, size=2.5)
plt.show()

# %%
correlation = train.corr()

import matplotlib.pyplot as plt
fig = plt.subplots(figsize=(10,10))
sb.heatmap(correlation,vmax=1,square=True,annot=True,cmap='Blues')

# %%
train[1:].plot.box()

# %%
sb.boxplot(y = train[3])

# %%
sb.boxplot(y = train[4])

# %%
train[0].value_counts()
# Out:
# M     3979
# F     3391
# I     2767
# --     388
# ?       54
# Name: 0, dtype: int64

# %%
train[0] = train.replace(['I', '--', '?'], np.NaN)
train[0].value_counts()
# Out:
# M    3979
# F    3391
# Name: 0, dtype: int64

# %%
train = pd.get_dummies(train)
train.head()
# Out:
#         1       2       3       4         5         6         7   8  0_F  0_M
# 0  3.1110  2.4990  0.8160  5.8446  3.044700  1.008515  1.992463   8    0    1
# 1  2.3715  1.8360  0.5355  2.1981  1.222069  0.545700  1.296961   9    0    1
# 2  2.4990  2.0145  0.7140  2.7999  1.129650  0.650250  0.765000  11    0    1
# 3  3.2130  2.5245  0.8160  5.5743  2.534700  1.127100  1.606500  12    0    1
# 4  2.9325  2.2185  0.6885  5.0592  2.203200  1.254302  1.296961  10    0    1

# %%
from sklearn.preprocessing import RobustScaler
X = train.values[:,[0,1,2,3,4,5,6,8,9]]
y = train.values[:, 7]
rs = RobustScaler(with_centering=True, with_scaling=True, quantile_range=(25.0, 75.0))
X_scaled = rs.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.25, shuffle=True, random_state=42)

# %%
scoring = 'accuracy'
seed = 7


models = []
models.append(('LR', LogisticRegression()))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC()))

results = []
names = []
for name, model in models:
    kfold = model_selection.KFold(n_splits=10, random_state=seed)
    cv_results = model_selection.cross_val_score(model, X_train, y_train, cv=kfold, scoring=scoring)
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# LR: 0.308543 (0.011874)
# LDA: 0.303629 (0.009142)
# KNN: 0.352027 (0.012677)
# CART: 0.556592 (0.014759)
# NB: 0.301865 (0.014842)
# SVM: 0.322160 (0.010919)

# %%
svc = SVC()
svc.fit(X_train, y_train)
predictions = svc.predict(X_test)
print('Accuracy on unseen data:')
print(accuracy_score(y_test, predictions))
print('\nClassification report:')
print(classification_report(y_test, predictions))
# Out:
# Accuracy on unseen data:
# 0.3217391304347826
#
# Classification report:
#              precision    recall  f1-score   support
#
#         7.0       0.53      0.54      0.54       306
#         8.0       0.39      0.31      0.34       448
#         9.0       0.26      0.54      0.35       542
#        10.0       0.28      0.32      0.30       514
#        11.0       0.33      0.23      0.27       388
#        12.0       0.00      0.00      0.00       211
#        13.0       0.00      0.00      0.00       171
#        16.0       0.00      0.00      0.00        65
#
# avg / total       0.28      0.32      0.29      2645
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
dc = DecisionTreeClassifier()
dc.fit(X_train, y_train)
predictions = dc.predict(X_test)
print('Accuracy on unseen data:')
print(accuracy_score(y_test, predictions))
print('\nClassification report:')
print(classification_report(y_test, predictions))
# Out:
# Accuracy on unseen data:
# 0.5992438563327032
#
# Classification report:
#              precision    recall  f1-score   support
#
#         7.0       0.65      0.66      0.65       306
#         8.0       0.62      0.65      0.63       448
#         9.0       0.57      0.60      0.59       542
#        10.0       0.60      0.59      0.60       514
#        11.0       0.61      0.60      0.61       388
#        12.0       0.52      0.52      0.52       211
#        13.0       0.58      0.48      0.52       171
#        16.0       0.69      0.58      0.63        65
#
# avg / total       0.60      0.60      0.60      2645

# %%
knc = KNeighborsClassifier()
knc.fit(X_train, y_train)
predictions = knc.predict(X_test)
print('Accuracy on unseen data:')
print(accuracy_score(y_test, predictions))
print('\nClassification report:')
print(classification_report(y_test, predictions))
# Out:
# Accuracy on unseen data:
# 0.3667296786389414
#
# Classification report:
#              precision    recall  f1-score   support
#
#         7.0       0.44      0.64      0.52       306
#         8.0       0.33      0.37      0.35       448
#         9.0       0.34      0.41      0.37       542
#        10.0       0.36      0.38      0.37       514
#        11.0       0.40      0.32      0.36       388
#        12.0       0.31      0.18      0.22       211
#        13.0       0.33      0.15      0.21       171
#        16.0       0.47      0.14      0.21        65
#
# avg / total       0.36      0.37      0.36      2645

# %%
from scipy.misc import comb
import math
def ensemble_error (n_classifier , error) :
    k_start = int(math.ceil(n_classifier / 2.0)) 
    probs = [comb(n_classifier , k) *error**k *(1 - error)**(n_classifier - k) for k in range(k_start , n_classifier + 1) ]
    return sum(probs)
#ensemble_error (n_classifier=ll, error=0.25)

# %%
error_range = np.arange(0.0 , 1.01, 0.01)
ens_errors = [ensemble_error(n_classifier=11, error=error) for error in error_range]

plt.plot(error_range , ens_errors, lаbеl='Ансамблевая ошибка',linewidth=2)
plt.plot(error_range, error_range,linestyle='--', lаbеl= 'Базовая ошибка',linewidth=2)
рlt.х_test('Базовая ошибка ')
рlt.у_test('Базовая/ансамблевая ошибка ')
plt.legend(loc= ' upper left')
plt.grid()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: `comb` is deprecated!
# Importing `comb` from scipy.misc is deprecated in scipy 1.0.0. Use `scipy.special.comb` instead.
#   """
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-030a896bbbf1> in <module>()
#       3 ens_errors = [ensemble_error(n_classifier=11, error=error) for error in error_range]
#       4
# ----> 5 plt.plot(error_range , ens_errors, lаbеl='Ансамблевая ошибка',linewidth=2)
#       6 plt.plot(error_range, error_range,linestyle='--', lаbеl= 'Базовая ошибка',linewidth=2)
#       7 рlt.х_test('Базовая ошибка ')
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3259                       mplDeprecation)
#    3260     try:
# -> 3261         ret = ax.plot(*args, **kwargs)
#    3262     finally:
# ...
